# %%
from datasets import load_dataset

dataset = load_dataset("fashion_mnist")
label_to_str = {
    0: "T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot",
}
# Out:
# Reusing dataset fashion_mnist (/Users/anton164/.cache/huggingface/datasets/fashion_mnist/fashion_mnist/1.0.0/8d6c32399aa01613d96e2cbc9b13638f359ef62bb33612b077b4c247f6ef99c1)
# 100%|██████████| 2/2 [00:00<00:00, 527.25it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
from IPython.display import display
for example in dataset["train"].select(range(10)):
    label = example["label"]
    print(f"{label_to_str[label]} ({label})")
    display(example["image"])
# Out:
# Ankle boot (9)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# T-shirt/top (0)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# T-shirt/top (0)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# Dress (3)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# T-shirt/top (0)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# Pullover (2)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# Sneaker (7)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# Pullover (2)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# Sandal (5)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
# Sandal (5)
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>
